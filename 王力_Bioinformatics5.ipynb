# %% [markdown]
# <a href="https://colab.research.google.com/github/bolsunbek/Wangli/blob/main/%E7%8E%8B%E5%8A%9B_Bioinformatics5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (from lazypredict) (0.90)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.8/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from lightgbm->lazypredict) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lazypredict) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lazypredict) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/bolsunbek/data.Wangli/raw/main/wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2023-02-15 11:03:39--  https://github.com/bolsunbek/data.Wangli/raw/main/wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/bolsunbek/data.Wangli/main/wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2023-02-15 11:03:40--  https://raw.githubusercontent.com/bolsunbek/data.Wangli/main/wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’
#
# wangli_acetylcholin 100%[===================>]   7.98M  --.-KB/s    in 0.04s
#
# 2023-02-15 11:03:40 (209 MB/s) - ‘wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’ saved [8363909/8363909]

# %%
df = pd.read_csv('wangli_acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  95%|█████████▌| 40/42 [30:54<01:32, 46.02s/it]
# [11:35:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 42/42 [30:56<00:00, 44.20s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#  95%|█████████▌| 40/42 [30:25<01:27, 43.54s/it]
# [12:05:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 42/42 [30:27<00:00, 43.50s/it]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                         Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                   0.86
# DecisionTreeRegressor                                 0.86
# ExtraTreeRegressor                                    0.86
# GaussianProcessRegressor                              0.86
# RandomForestRegressor                                 0.82
# BaggingRegressor                                      0.80
# MLPRegressor                                          0.76
# HistGradientBoostingRegressor                         0.67
# LGBMRegressor                                         0.67
# KNeighborsRegressor                                   0.63
# SVR                                                   0.56
# NuSVR                                                 0.55
# GradientBoostingRegressor                             0.44
# XGBRegressor                                          0.44
# Ridge                                                 0.31
# LassoCV                                               0.30
# ElasticNetCV                                          0.30
# LinearRegression                                      0.30
# TransformedTargetRegressor                            0.30
# RidgeCV                                               0.30
# SGDRegressor                                          0.30
# BayesianRidge                                         0.29
# LassoLarsCV                                           0.29
# LassoLarsIC                                           0.29
# HuberRegressor                                        0.29
# LinearSVR                                             0.27
# PoissonRegressor                                      0.25
# AdaBoostRegressor                                     0.20
# OrthogonalMatchingPursuitCV                           0.20
# OrthogonalMatchingPursuit                             0.20
# TweedieRegressor                                      0.19
# GammaRegressor                                        0.19
# Lars                                                  0.14
# LarsCV                                                0.12
# Lasso                                                -0.04
# LassoLars                                            -0.04
# ElasticNet                                           -0.04
# DummyRegressor                                       -0.04
# QuantileRegressor                                    -0.05
# PassiveAggressiveRegressor                           -0.17
# KernelRidge                                         -14.25
# RANSACRegressor               -969557151594042273824768.00
#
#                                                  R-Squared             RMSE  \
# Model
# ExtraTreesRegressor                                   0.86             0.57
# DecisionTreeRegressor                                 0.86             0.57
# ExtraTreeRegressor                                    0.86             0.57
# GaussianProcessRegressor                              0.86             0.57
# RandomForestRegressor                                 0.83             0.64
# BaggingRegressor                                      0.81             0.67
# MLPRegressor                                          0.77             0.75
# HistGradientBoostingRegressor                         0.69             0.87
# LGBMRegressor                                         0.69             0.87
# KNeighborsRegressor                                   0.64             0.93
# SVR                                                   0.58             1.01
# NuSVR                                                 0.57             1.02
# GradientBoostingRegressor                             0.46             1.14
# XGBRegressor                                          0.46             1.14
# Ridge                                                 0.33             1.27
# LassoCV                                               0.33             1.27
# ElasticNetCV                                          0.33             1.27
# LinearRegression                                      0.33             1.27
# TransformedTargetRegressor                            0.33             1.27
# RidgeCV                                               0.33             1.27
# SGDRegressor                                          0.32             1.28
# BayesianRidge                                         0.32             1.28
# LassoLarsCV                                           0.32             1.28
# LassoLarsIC                                           0.32             1.28
# HuberRegressor                                        0.31             1.29
# LinearSVR                                             0.30             1.30
# PoissonRegressor                                      0.28             1.32
# AdaBoostRegressor                                     0.23             1.36
# OrthogonalMatchingPursuitCV                           0.23             1.37
# OrthogonalMatchingPursuit                             0.23             1.37
# TweedieRegressor                                      0.22             1.37
# GammaRegressor                                        0.22             1.37
# Lars                                                  0.18             1.41
# LarsCV                                                0.15             1.43
# Lasso                                                 0.00             1.55
# LassoLars                                             0.00             1.55
# ElasticNet                                            0.00             1.55
# DummyRegressor                                        0.00             1.55
# QuantileRegressor                                    -0.01             1.56
# PassiveAggressiveRegressor                           -0.13             1.65
# KernelRidge                                         -13.70             5.95
# RANSACRegressor               -934183162308187629027328.00 1500506070914.21
#
#                                Time Taken
# Model
# ExtraTreesRegressor                  6.68
# DecisionTreeRegressor                0.15
# ExtraTreeRegressor                   0.12
# GaussianProcessRegressor             6.30
# RandomForestRegressor                4.06
# BaggingRegressor                     0.50
# MLPRegressor                         9.38
# HistGradientBoostingRegressor        1.19
# LGBMRegressor                        0.53
# KNeighborsRegressor                  0.51
# SVR                                  5.16
# NuSVR                                2.86
# GradientBoostingRegressor            1.59
# XGBRegressor                         1.30
# Ridge                                0.08
# LassoCV                              4.04
# ElasticNetCV                         3.93
# LinearRegression                     0.13
# TransformedTargetRegressor           0.07
# RidgeCV                              0.23
# SGDRegressor                         0.19
# BayesianRidge                        0.21
# LassoLarsCV                          0.37
# LassoLarsIC                          0.14
# HuberRegressor                       0.31
# LinearSVR                            0.92
# PoissonRegressor                     0.10
# AdaBoostRegressor                    0.74
# OrthogonalMatchingPursuitCV          0.12
# OrthogonalMatchingPursuit            0.05
# TweedieRegressor                     0.06
# GammaRegressor                       0.08
# Lars                                 0.22
# LarsCV                               0.86
# Lasso                                0.05
# LassoLars                            0.10
# ElasticNet                           0.04
# DummyRegressor                       0.03
# QuantileRegressor                 1799.81
# PassiveAggressiveRegressor           0.10
# KernelRidge                          1.99
# RANSACRegressor                      1.09

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                          Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                          0.46
# LGBMRegressor                                          0.46
# RandomForestRegressor                                  0.44
# BaggingRegressor                                       0.41
# NuSVR                                                  0.39
# SVR                                                    0.39
# KNeighborsRegressor                                    0.37
# MLPRegressor                                           0.36
# GradientBoostingRegressor                              0.33
# XGBRegressor                                           0.32
# ExtraTreesRegressor                                    0.22
# DecisionTreeRegressor                                  0.20
# TransformedTargetRegressor                             0.20
# LinearRegression                                       0.20
# Ridge                                                  0.20
# RidgeCV                                                0.20
# ElasticNetCV                                           0.20
# LassoCV                                                0.20
# ExtraTreeRegressor                                     0.20
# SGDRegressor                                           0.19
# BayesianRidge                                          0.19
# LassoLarsIC                                            0.19
# LassoLarsCV                                            0.19
# HuberRegressor                                         0.19
# LinearSVR                                              0.16
# PoissonRegressor                                       0.16
# OrthogonalMatchingPursuit                              0.11
# OrthogonalMatchingPursuitCV                            0.11
# GammaRegressor                                         0.08
# TweedieRegressor                                       0.08
# AdaBoostRegressor                                      0.07
# Lars                                                   0.01
# LarsCV                                                 0.01
# DummyRegressor                                        -0.17
# ElasticNet                                            -0.17
# LassoLars                                             -0.17
# Lasso                                                 -0.17
# QuantileRegressor                                     -0.19
# PassiveAggressiveRegressor                            -0.42
# GaussianProcessRegressor                              -6.02
# KernelRidge                                          -16.36
# RANSACRegressor               -1293509306613648196632576.00
#
#                                                   R-Squared             RMSE  \
# Model
# HistGradientBoostingRegressor                          0.54             1.06
# LGBMRegressor                                          0.54             1.06
# RandomForestRegressor                                  0.52             1.08
# BaggingRegressor                                       0.49             1.11
# NuSVR                                                  0.48             1.12
# SVR                                                    0.48             1.12
# KNeighborsRegressor                                    0.47             1.14
# MLPRegressor                                           0.45             1.15
# GradientBoostingRegressor                              0.42             1.18
# XGBRegressor                                           0.42             1.18
# ExtraTreesRegressor                                    0.34             1.27
# DecisionTreeRegressor                                  0.32             1.28
# TransformedTargetRegressor                             0.32             1.28
# LinearRegression                                       0.32             1.28
# Ridge                                                  0.32             1.28
# RidgeCV                                                0.32             1.28
# ElasticNetCV                                           0.32             1.28
# LassoCV                                                0.32             1.28
# ExtraTreeRegressor                                     0.32             1.29
# SGDRegressor                                           0.31             1.29
# BayesianRidge                                          0.31             1.29
# LassoLarsIC                                            0.31             1.29
# LassoLarsCV                                            0.31             1.29
# HuberRegressor                                         0.31             1.29
# LinearSVR                                              0.28             1.32
# PoissonRegressor                                       0.28             1.32
# OrthogonalMatchingPursuit                              0.24             1.36
# OrthogonalMatchingPursuitCV                            0.24             1.36
# GammaRegressor                                         0.22             1.37
# TweedieRegressor                                       0.22             1.38
# AdaBoostRegressor                                      0.21             1.38
# Lars                                                   0.16             1.43
# LarsCV                                                 0.15             1.43
# DummyRegressor                                        -0.00             1.55
# ElasticNet                                            -0.00             1.55
# LassoLars                                             -0.00             1.55
# Lasso                                                 -0.00             1.55
# QuantileRegressor                                     -0.02             1.57
# PassiveAggressiveRegressor                            -0.22             1.71
# GaussianProcessRegressor                              -4.99             3.80
# KernelRidge                                          -13.82             5.98
# RANSACRegressor               -1104585239442998180184064.00 1632314539157.40
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        2.95
# LGBMRegressor                        0.47
# RandomForestRegressor                3.98
# BaggingRegressor                     0.47
# NuSVR                                1.66
# SVR                                  2.70
# KNeighborsRegressor                  0.17
# MLPRegressor                         9.62
# GradientBoostingRegressor            1.55
# XGBRegressor                         1.15
# ExtraTreesRegressor                  6.59
# DecisionTreeRegressor                0.16
# TransformedTargetRegressor           0.07
# LinearRegression                     0.08
# Ridge                                0.05
# RidgeCV                              0.16
# ElasticNetCV                         3.89
# LassoCV                              4.04
# ExtraTreeRegressor                   0.19
# SGDRegressor                         0.21
# BayesianRidge                        0.11
# LassoLarsIC                          0.16
# LassoLarsCV                          0.35
# HuberRegressor                       0.27
# LinearSVR                            0.76
# PoissonRegressor                     0.09
# OrthogonalMatchingPursuit            0.04
# OrthogonalMatchingPursuitCV          0.13
# GammaRegressor                       0.06
# TweedieRegressor                     0.10
# AdaBoostRegressor                    0.69
# Lars                                 0.11
# LarsCV                               0.38
# DummyRegressor                       0.03
# ElasticNet                           0.03
# LassoLars                            0.05
# Lasso                                0.06
# QuantileRegressor                 1776.87
# PassiveAggressiveRegressor           0.10
# GaussianProcessRegressor             4.19
# KernelRidge                          1.15
# RANSACRegressor                      1.04

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
